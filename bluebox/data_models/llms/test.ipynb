# %%
from bluebox.data_models.llms.vendors import (
    LLMVendor,
    OpenAIModel,
    AnthropicModel,
    get_model_vendor,
    get_model_by_value,
    get_all_model_values,
)
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ec2-user/bluebox-sdk/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print(
    get_all_model_values()
)
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ec2-user/bluebox-sdk/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
